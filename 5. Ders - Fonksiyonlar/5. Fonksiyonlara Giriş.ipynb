# %% [markdown]
# # ... ve nihayet: Fonksiyonlar!

# %% [markdown]
# Spamlık Ticaret adında bir firma tarafından bir iş teklifi aldınız. 5 farklı müşteri isim listesi olduğunu söylediler. Her bir listeye aşağıdaki maili atmanızı istiyorlar.
#
# ```
#   Merhaba Ali Konuk,
#   Bu ay size özel harika bir indirimimiz var!
#   Tek yapmanız gereken aşağıdaki linke tıklamak:
#   www.spamlikticaret.com/harika-indirim
#
#   İyi günler dileriz.
# ```
#
#
# Döngüler konusuna hakim olduğunuz için içinizden "*bu çok basit bir iş*" dediniz ve hemen işi kaptınız.

# %%
liste1 = ['Halit Çevik', 'Zeynep Kayran', 'Burçin Gün']
liste2 = ['Bülent Işçi', 'Kadir Çalışkan','Süheyla Yılmaz']
liste3 = ['Nilüfer Eryılmaz', 'Fatma Ceylan', 'Hüseyin Deniz']
liste4 = ['Nilay Durmaz','Tahir Basmaz', 'Ibrahim Tuncay']
liste5 = ['Melike Akdaş', 'Saniye Gül', 'Ceylan Aksu']

# %%
for isim in liste1:
  print('Merhaba ' + isim)
  print('Bu ay size özel harika bir indirimimiz var!')
  print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
  print('www.spamlikticaret.com/harika-indirim')
  print('İyi günler dileriz.')
# Out:
# Merhaba Halit Çevik
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Zeynep Kayran
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Burçin Gün
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste2:
  print('Merhaba ' + isim)
  print('Bu ay size özel harika bir indirimimiz var!')
  print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
  print('www.spamlikticaret.com/harika-indirim')
  print('İyi günler dileriz.')
# Out:
# Merhaba Bülent Işçi
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Kadir Çalışkan
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Süheyla Yılmaz
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste3:
  print('Merhaba ' + isim)
  print('Bu ay size özel harika bir indirimimiz var!')
  print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
  print('www.spamlikticaret.com/harika-indirim')
  print('İyi günler dileriz.')
# Out:
# Merhaba Nilüfer Eryılmaz
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Fatma Ceylan
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Hüseyin Deniz
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste4:
  print('Merhaba ' + isim)
  print('Bu ay size özel harika bir indirimimiz var!')
  print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
  print('www.spamlikticaret.com/harika-indirim')
  print('İyi günler dileriz.')
# Out:
# Merhaba Nilay Durmaz
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Tahir Basmaz
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Ibrahim Tuncay
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste5:
  print('Merhaba ' + isim)
  print('Bu ay size özel harika bir indirimimiz var!')
  print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
  print('www.spamlikticaret.com/harika-indirim')
  print('İyi günler dileriz.')
# Out:
# Merhaba Melike Akdaş
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Saniye Gül
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Ceylan Aksu
# Bu ay size özel harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %% [markdown]
# Tam döngüleri hazırlamışken bir haber geldi, "size özel" kısmını büyük harflerle yazmanızı istiyorlarmış 😒 İlk hissiyatınız tabii ki: üşengeçlik. Eliniz tam ctrl+c'ye giderken içinizden şöyle bir şey geçmeye başladı: Tekrar tekrar aynı şeyi kopyalayacağıma elimde mailin bir **şablon**u olsaydı da sadece onu değiştirseydim?
#
# İşte programlamada bu **şablon**lara **fonksiyon** deniyor ve siz bir gün teşekkür edeceğinizi hiç ummadığınız içinizdeki tembel sayesinde bu kapıyı açtınız 🥳
#
# Fonksiyonlar şu şekilde tanımlanır:
#
#
# ```
# def fonksiyon_adı():
#   yapılacak işler
# ```

# %%
def mail_metni():
  print('Bu ay SİZE ÖZEL harika bir indirimimiz var!')
  print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
  print('www.spamlikticaret.com/harika-indirim')
  print('İyi günler dileriz.')

# %% [markdown]
# Kodu çalıştırdık ama hiç print yok? Çünkü fonksiyonu **çağırmadık (çalıştırmadık).** Sadece çağırıldığında ne yapacağını yazdık. Fonksiyonlar aşağıdaki gibi çağırılır:

# %%
mail_metni()
# Out:
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %% [markdown]
# İşte bu sefer metni tek yerden düzeltebiliriz!

# %%
for isim in liste1:
  print('Merhaba ' + isim)
  mail_metni()
# Out:
# Merhaba Halit Çevik
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Zeynep Kayran
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Burçin Gün
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste2:
  print('Merhaba ' + isim)
  mail_metni()
# Out:
# Merhaba Bülent Işçi
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Kadir Çalışkan
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Süheyla Yılmaz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste3:
  print('Merhaba ' + isim)
  mail_metni()
# Out:
# Merhaba Nilüfer Eryılmaz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Fatma Ceylan
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Hüseyin Deniz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste4:
  print('Merhaba ' + isim)
  mail_metni()
# Out:
# Merhaba Nilay Durmaz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Tahir Basmaz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Ibrahim Tuncay
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %%
for isim in liste5:
  print('Merhaba ' + isim)
  mail_metni()
# Out:
# Merhaba Melike Akdaş
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Saniye Gül
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# Merhaba Ceylan Aksu
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %% [markdown]
# Elleriniz fonksiyonların bu fevkaladeliğinin heyecanıyla titremeye başlamışken aklınıza daha da tembel bir fikir geldi: Bu listeleri de tek tek yazmasaydım ne güzel olurdu!
#
# O halde **şablon**umuz için **boşluklar/değişkenler** gerekiyor: **PARAMETRELER!**
#
# Önce basit bir fonksiyon yazalım:

# %%
def karşılama(isim):
  print(f"Hoş geldiniz {isim}")

# %%
karşılama('Ali')
# Out:
# Hoş geldiniz Ali

# %%
isimler = ['Ayşe','Ali','Zeynep']
for ad in isimler:
  karşılama(ad)
# Out:
# Hoş geldiniz Ayşe
# Hoş geldiniz Ali
# Hoş geldiniz Zeynep

# %%
for isim in liste1:
  karşılama(isim)
# Out:
# Hoş geldiniz Halit Çevik
# Hoş geldiniz Zeynep Kayran
# Hoş geldiniz Burçin Gün

# %% [markdown]
# Parametre olarak string alabiliyorsak tabii ki liste de alabiliriz o halde:

# %%
def mail_at(isim_listesi):
  for isim in isim_listesi:
    print('MERHABA ' + isim)
    print('Bu ay SİZE ÖZEL harika bir indirimimiz var!')
    print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
    print('www.spamlikticaret.com/harika-indirim')
    print('İyi günler dileriz.')

# %%
mail_at(liste1)
# Out:
# MERHABA Halit Çevik
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Zeynep Kayran
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Burçin Gün
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.

# %% [markdown]
# İşte kodlamada çağ atladığımızı hissettiğimiz an 🚀

# %%
mail_at(liste1)
mail_at(liste2)
mail_at(liste3)
mail_at(liste4)
mail_at(liste5)
# Out:
# MERHABA Halit Çevik
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Zeynep Kayran
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Burçin Gün
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Bülent Işçi
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Kadir Çalışkan
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Süheyla Yılmaz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# ...

# %% [markdown]
# Hatta biraz daha ileri gidelim listelerin listesini yapalım (_evet bu bir çılgınlık_) ve bu işi sadece 3 satırda bitirelim:

# %%
# Listeler listesi örneği
isimler1 = ['ali','ayşe']
isimler2 = ['kerem','fatma']
sınıflar = [isimler1, isimler2]
print(sınıflar)
# Out:
# [['ali', 'ayşe'], ['kerem', 'fatma']]

# %%
isim_listeleri = [liste1, liste2, liste3, liste4, liste5]
for liste in isim_listeleri:
  mail_at(liste)
# Out:
# MERHABA Halit Çevik
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Zeynep Kayran
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Burçin Gün
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Bülent Işçi
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Kadir Çalışkan
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# Tek yapmanız gereken aşağıdaki linke tıklamak:
# www.spamlikticaret.com/harika-indirim
# İyi günler dileriz.
# MERHABA Süheyla Yılmaz
# Bu ay SİZE ÖZEL harika bir indirimimiz var!
# ...

# %% [markdown]
# Artık bir değişiklik yapmak istediğimizde tek yapmamız gereken yukarıda tanımladığımız
# ```
# def mail_at(liste):
#   for isim in liste:
#     print('Merhaba ' + isim)
#     print('Bu ay SİZE ÖZEL harika bir indirimimiz var!')
#     print('Tek yapmanız gereken aşağıdaki linke tıklamak:')
#     print('www.spamlikticaret.com/harika-indirim')
#     print('İyi günler dileriz.')
# ```
#
# fonksiyonunda değişiklik yapmak. Böylece daha önce aynı kodu 5 farklı yerde yazmıştık ve bir problem olduğunda 5 yerde değişiklik yapmak zorunda kalmıştık. Şimdiyse tembellikten doğan zaferimizin coşkusunu hissettiğimiz gurur dolu bir andayız 😎
#
# Fonksiyon yazmanın mantığı aslında değişken kullanmaya benziyor. 10 farklı yerde aynı bilgiyi kullanacaksak onu bir değişken olarak tanımlamanın daha mantıklı olduğunu daha önce görmüştük. Çünkü aynı şekilde değişken kullanmak 10 farklı yerde düzeltme yapmak yerine tek bir yerden 10 noktayı kontrol edebilmemizi sağlıyordu. Artık bu yaklaşımı kodlarda da kullanabiliriz 💣

# %% [markdown]
# # Fonksiyonlar: Resmi Bir Giriş

# %% [markdown]
# ## Parametreler ve Argümanlar

# %% [markdown]
# Yukarıda öğrendiğimiz üzere fonksiyonlar hem parametreli hem parametresiz tanımlanabilir. Bu tamamen bizim seçimimize bağlı.

# %%
def karşılama():
  print('Hoş geldiniz,')
  print('Harika bir gösteri sizi bekliyor :)')

# %% [markdown]
# ve çok önemli bir bilgiyi tekrar hatırlatalım, bir fonksiyon **çağırılmadığı sürece çalışmaz.**

# %%
karşılama()
# Out:
# Hoş geldiniz,
# Harika bir gösteri sizi bekliyor :)

# %% [markdown]
# Parametreli bir fonksiyon tanımlayalım.

# %%
def karşılama(isim):
  print(f"Hoş geldiniz {isim},")
  print('Harika bir gösteri sizi bekliyor :)')

# %%
karşılama('Ali')
# Out:
# Hoş geldiniz Ali,
# Harika bir gösteri sizi bekliyor :)

# %% [markdown]
# Ah bir şey unuttuk! Hiç hata almadık, hemen bir tane alalım 🤗

# %%
karşılama()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-b1b37cf6959e> in <module>
# ----> 1 karşılama()
#
# TypeError: karşılama() missing 1 required positional argument: 'isim'

# %% [markdown]
# Hmm, demek ki bir parametre tanımlamışsak daima onun için bir değer (argument) vermeliyiz. Peki oldu ki kullanıcı ismini öğrenemedik ama yine de bu fonksiyonu çalıştırmamız gerekiyor. O halde **default argument** kullanacağız:

# %%
def karşılama(isim='kıymetli misafirimiz'):
  print(f"Hoş geldiniz {isim},")
  print('Harika bir gösteri sizi bekliyor :)')

# %%
karşılama()
# Out:
# Hoş geldiniz kıymetli misafirimiz,
# Harika bir gösteri sizi bekliyor :)

# %%
karşılama('Ali')
# Out:
# Hoş geldiniz Ali,
# Harika bir gösteri sizi bekliyor :)

# %% [markdown]
# Problem çözüldü, şahane!
#
# İlla tek bir parametre mi yazmak zorundayız? Elbette HAYIR

# %%
def karşılama(isim, soyad):
  print(f"Hoş geldiniz sayın {isim} {soyad},")
  print('Harika bir gösteri sizi bekliyor :)')

# %%
x = 'ali'
y = 'yıldırım'
karşılama(x, y)
# Out:
# Hoş geldiniz sayın ali yıldırım,
# Harika bir gösteri sizi bekliyor :)

# %% [markdown]
# Bu tanımladığımız fonksiyonu bir arkadaşımıza gönderdik, arkadaşımız ilk başta isim yerine soyad, ikinci olarak da isim girmiş ve garip bir şeyle karşılaşmış:

# %%
karşılama('Yıldırım','Ali')
# Out:
# Hoş geldiniz sayın Yıldırım Ali,
# Harika bir gösteri sizi bekliyor :)

# %% [markdown]
# Demek ki parametreler için verdiğimiz değerlerin (argument) __konum__ları önemliymiş! Buna **positional argument** deniyor. E ama ben içeriğini hiç bilmediğim bir fonksiyonda hangi parametrenin kaçıncı sırada olduğunu nereden bileceğim? İşte bunu bilmenin imkansızlığından dolayı şu şekilde de fonksiyonları kullanabiliyoruz.

# %%
karşılama(soyad='Yıldırım', isim='Ali')
# Out:
# Hoş geldiniz sayın Ali Yıldırım,
# Harika bir gösteri sizi bekliyor :)

# %% [markdown]
# Bu şekilde kullanıma **keyword argument** deniyor.
#
# Burada dikkat etmemiz gereken şey, bir kere keyword argument kullandıysak, sonrasında positional argument **kullanamayız.** Yoksa aşağıdaki hatayı alırız:

# %%
karşılama(soyad='Yıldırım','Ali')
# Out:
#   File "<ipython-input-36-559a5e8a5c94>", line 1
#     karşılama(soyad='Yıldırım','Ali')
#                                    ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# Neticede 3 farklı şekilde parametre kullanabiliriz:
# 1. Default Argument
# 2. Positional Argument
# 3. Keyword Argument

# %% [markdown]
# Bu kadar teori yeter, biraz fonksiyon yazalım 🏄‍♂️

# %% [markdown]
# ## Not Ortalaması Hesaplama

# %%
def ortalama_hesapla(vize, final, vize_yüzde=40, final_yüzde=60):
  ortalama = (vize * vize_yüzde / 100) + (final * final_yüzde / 100)
  print("Not ortalamanız: " + str(ortalama))

# %%
ortalama_hesapla(40, 50)
# Out:
# Not ortalamanız: 46.0

# %%
# Final %100 vize %0 etkili olsaydı:
ortalama_hesapla(40, 50, 0, 100)
# Out:
# Not ortalamanız: 50.0

# %%
ortalama_hesapla(40, 50, 0, 100)
# Out:
# Not ortalamanız: 50.0

# %%
# keyword argument kullandığımızda sıralamanın önemli olmadığını daha önce görmüştük
ortalama_hesapla(vize_yüzde=50, final=100, final_yüzde=50, vize=80)
# Out:
# Not ortalamanız: 90.0

# %% [markdown]
# Liste içinde liste kullanımını biraz daha öğrenelim. Her öğrencinin vize ve final notunu liste halinde tutan bir liste yazalım.

# %%
notlar = [['Ali',95, 68], ['Serap', 59, 48], ['Yıldız', 70, 89], ['Fatih', 83, 75], ['Lale', 53, 95]]

# 2. öğrencinin adı (saymaya sıfırdan başlıyoruz)
notlar[2][0]
# Out:
# 'Yıldız'

# %%
notlar = [['Ali',95, 68], ['Serap', 59, 48], ['Yıldız', 70, 89], ['Fatih', 83, 75], ['Lale', 53, 95]]
for puanlar_listesi in notlar:
  print(puanlar_listesi)
# Out:
# ['Ali', 95, 68]
# ['Serap', 59, 48]
# ['Yıldız', 70, 89]
# ['Fatih', 83, 75]
# ['Lale', 53, 95]

# %% [markdown]
# Döngü yazdığımızda notları taşıyan listelere tek tek erişebiliyoruz. O halde her bir listenin ilk elemanını vize, ikinci elemanını final şeklinde ekrana yazdırabiliriz:

# %%
for puanlar in notlar:
  print(f"Öğrenci adı: {puanlar[0]}")
  print(f"Vize: {puanlar[1]}")
  print(f"Final: {puanlar[2]}")
  print('-'*20)
# Out:
# Öğrenci adı: Ali
# Vize: 95
# Final: 68
# --------------------
# Öğrenci adı: Serap
# Vize: 59
# Final: 48
# --------------------
# Öğrenci adı: Yıldız
# Vize: 70
# Final: 89
# --------------------
# Öğrenci adı: Fatih
# Vize: 83
# Final: 75
# --------------------
# Öğrenci adı: Lale
# Vize: 53
# Final: 95
# --------------------

# %% [markdown]
# Yukarıda yazdığımız ortalama alma fonksiyonunu kullanarak her bir öğrencinin ortalamasını bulalım:

# %%
# Hatırlatma
def ortalama_hesapla(vize, final, vize_yüzde=40, final_yüzde=60):
  ortalama = (vize * vize_yüzde / 100) + (final * final_yüzde / 100)
  print("Not ortalamanız: " + str(ortalama))

# %%
for puanlar in notlar:
  print(f"Sevgili {puanlar[0]}")
  ortalama_hesapla(puanlar[1], puanlar[2], vize_yüzde = 60, final_yüzde=40)
  print('-'*10)
# Out:
# Sevgili Ali
# Not ortalamanız: 84.2
# ----------
# Sevgili Serap
# Not ortalamanız: 54.599999999999994
# ----------
# Sevgili Yıldız
# Not ortalamanız: 77.6
# ----------
# Sevgili Fatih
# Not ortalamanız: 79.8
# ----------
# Sevgili Lale
# Not ortalamanız: 69.8
# ----------

# %% [markdown]
# # Fonksiyonların Çıktısı: Return

# %% [markdown]
# Yukarıda öğrencilerin not ortalamasını bulduk, ekrana yazdırabildik fakat <strong>kullanamadık</strong>. Öğrenciye sadece not ortalamasını yazdırmak yerine hangi harf notunu aldığını gösteren bir program yazmak isteseydik ne yapacaktık 🤔
#
# Tıpkı daha önce kullandığımız <strong>len()</strong> fonksiyonu gibi bizim fonksiyonumuz da istediğimiz bilgiyi ekrana yazmak yerine kodumuzun içerisinde kullanmamız için bize verse?
#
# İşte bu sebeple fonksiyonun yaptığı işlemin sonucunu kodumuzun devamında kullanacaksak **return** kullanmalıyız. **return** kodun çıktısını bir <strong><font color="orange">değişkende tutabilmemizi</font></strong> sağlar.

# %%
def ortalama_hesapla(vize, final, vize_yüzde=40, final_yüzde=60):
  ortalama = (vize * vize_yüzde / 100) + (final * final_yüzde / 100)
  return ortalama

# %%
ortalama_bilgisi = ortalama_hesapla(70, 80)
print(f"Ortalamanız: {ortalama_bilgisi}")

# bu ortalama_bilgisi değişkenini dilediğimiz şekilde kullanabiliriz:
if ortalama_bilgisi >= 90:
  print("Harf notunuz A, harikasınız!")
elif ortalama_bilgisi >= 75:
  print("Harf notunuz B, tebrikler!")
elif ortalama_bilgisi >= 65:
  print("Harf notunuz C, bir dahakine biraz daha gayret :)")
elif ortalama_bilgisi >= 50:
  print("Harf notunuz D, ucuz atlattın! :)")
else:
  print("Üzgünüm, dersten kaldınız :/")
# Out:
# Ortalamanız: 76.0
# Harf notunuz B, tebrikler!

# %% [markdown]
# Şimdi tüm öğrencilere harf notu bilgisini verelim:

# %%
notlar = [['Ali', 20, 41], ['Serap', 89, 48], ['Yıldız', 75, 85], ['Fatih', 83, 66], ['Lale', 90, 95]]
for puanlar in notlar:
  ortalama = ortalama_hesapla(puanlar[1], puanlar[2])
  print(f"Sevgili {puanlar[0]}, ortalamanız {ortalama:.2f}")
  if ortalama >= 90:
    print("Harf notunuz A, harikasınız!")
  elif ortalama >= 80:
    print("Harf notunuz B, tebrikler!")
  elif ortalama >= 70:
    print("Harf notunuz C, bir dahakine biraz daha gayret :)")
  elif ortalama >= 60:
    print("Harf notunuz D, ucuz atlattın! :)")
  else:
    print("Üzgünüm, dersten kaldınız :/")
  
  print('-'*20)
# Out:
# Sevgili Ali, ortalamanız 32.60
# Üzgünüm, dersten kaldınız :/
# --------------------
# Sevgili Serap, ortalamanız 64.40
# Harf notunuz D, ucuz atlattın! :)
# --------------------
# Sevgili Yıldız, ortalamanız 81.00
# Harf notunuz B, tebrikler!
# --------------------
# Sevgili Fatih, ortalamanız 72.80
# Harf notunuz C, bir dahakine biraz daha gayret :)
# --------------------
# Sevgili Lale, ortalamanız 93.00
# Harf notunuz A, harikasınız!
# --------------------

# %% [markdown]
# <i>`ortalama:.2f` kullanımı ondalıklı sayılarda virgülden sonra kaç basamak göstermesini istediğimizi belirtiyor. </i>

# %% [markdown]
# # Çeşitli Return Kullanımları

# %% [markdown]
# Yukarıdaki harf notu hesaplayan kodumuz epey kullanışlı, onu da bir fonksiyona dönüştürsek?

# %%
def harf_notu_hesapla(ortalama):
  if ortalama >= 90:
    return 'A'
  elif ortalama >= 75:
    return 'B'
  elif ortalama >= 65:
    return 'C'
  elif ortalama >= 50:
    return 'D'
  else:
    return 'F'

# %%
# ortalama_hesaplama kodumuzu hatırlayalım
def ortalama_hesapla(vize, final, vize_yüzde=40, final_yüzde=60):
  ortalama = (vize * vize_yüzde / 100) + (final * final_yüzde / 100)
  return ortalama

# %% [markdown]
# Böylelikle iki bilgiyi de dilediğimiz gibi kullanabilir, hatta <strong> ortalama_hesapla()</strong> fonksiyonundan elde ettiğimiz sayıyı <strong>harf_notu_hesapla()</strong> fonksiyonuna verebiliriz:

# %%
ortalama_puan = ortalama_hesapla(90,70)
harf_notu = harf_notu_hesapla(ortalama_puan)
print(f"Ortalamanız: {ortalama_puan}, harf notunuz: {harf_notu}")
# Out:
# Ortalamanız: 78.0, harf notunuz: B

# %%
notlar = [['Ali', 20, 41], ['Serap', 89, 48], ['Yıldız', 75, 85], ['Fatih', 83, 66], ['Lale', 90, 95]]
for puanlar in notlar:
  ortalama_puan = ortalama_hesapla(puanlar[1], puanlar[2])
  harf_notu = harf_notu_hesapla(ortalama_puan)
  print(f"Sevgili {puanlar[0]}, ortalaman: {ortalama_puan:.2f}, harf notun {harf_notu}")
# Out:
# Sevgili Ali, ortalaman: 32.60, harf notun F
# Sevgili Serap, ortalaman: 64.40, harf notun D
# Sevgili Yıldız, ortalaman: 81.00, harf notun B
# Sevgili Fatih, ortalaman: 72.80, harf notun C
# Sevgili Lale, ortalaman: 93.00, harf notun A

# %% [markdown]
# Böylelikle Ali'den beklentilerimizi ayrıca dile getirebiliriz:

# %%
notlar = [['Ali', 20, 41], ['Serap', 89, 48], ['Yıldız', 75, 85], ['Fatih', 83, 66], ['Lale', 90, 95]]
for puanlar in notlar:
  ortalama_puan = ortalama_hesapla(puanlar[1], puanlar[2])
  harf_notu = harf_notu_hesapla(ortalama_puan)
  
  if puanlar[0] == 'Ali' and ortalama_puan < 70:
    print(f"Ali, not ortalaman {ortalama_puan:.2f} ve harf notun {harf_notu}")
    print("Kodlamayla uğraşmaktan derslerini ihmal ediyorsun gibi görünüyor 🤨")
  else:
    print(f"Sevgili {puanlar[0]}, ortalaman: {ortalama_puan:.2f}, harf notun {harf_notu}")
  
  print('-'*40)
# Out:
# Ali, not ortalaman 32.60 ve harf notun F
# Kodlamayla uğraşmaktan derslerini ihmal ediyorsun gibi görünüyor 🤨
# ----------------------------------------
# Sevgili Serap, ortalaman: 64.40, harf notun D
# ----------------------------------------
# Sevgili Yıldız, ortalaman: 81.00, harf notun B
# ----------------------------------------
# Sevgili Fatih, ortalaman: 72.80, harf notun C
# ----------------------------------------
# Sevgili Lale, ortalaman: 93.00, harf notun A
# ----------------------------------------

# %% [markdown]
# ## Gelecekten Küçük Bir Mesaj
# İleride **tuple** konusunda daha detaylı işleyeceğiz, şimdi sadece tadımlık nefis bir bilgi öğreneceğiz: __Aynı anda birden fazla değişken tanımlama!__

# %%
isim = 'Ali'
soyad = 'Şaşkın'

# %%
isim, soyad = 'Ali', 'Şaşkın'
print(isim)
print(soyad)
# Out:
# Ali
# Şaşkın

# %% [markdown]
# MÜTHİŞ! Şimdi bunu fonksiyonlara uygulayalım:

# %%
def ortalama_hesapla(vize, final, vize_yüzde=40, final_yüzde=60):
  ortalama = (vize * vize_yüzde / 100) + (final * final_yüzde / 100)
  
  if ortalama > 90:
    return ortalama, 'A'

  elif ortalama > 80:
    return ortalama, 'B'

  elif ortalama > 70:
    return ortalama, 'C'
    
  elif ortalama > 60:
    return ortalama, 'D'

  else:
    return ortalama, 'F'

# %%
ort, harf = ortalama_hesapla(60, 100)
print(f"Ortalamanız: {ort}, harf notunuz: {harf}")
# Out:
# Ortalamanız: 84.0, harf notunuz: B

# %%
for puanlar in notlar:
  ortalama, harf = ortalama_hesapla(puanlar[1], puanlar[2])
  print(f"Sevgili {puanlar[0]}, ortalaman {ortalama:.2f} ve harf notun {harf}")
# Out:
# Sevgili Ali, ortalaman 32.60 ve harf notun F
# Sevgili Serap, ortalaman 52.40 ve harf notun F
# Sevgili Yıldız, ortalaman 49.00 ve harf notun F
# Sevgili Fatih, ortalaman 55.40 ve harf notun F
# Sevgili Lale, ortalaman 78.20 ve harf notun C

# %% [markdown]
# # Built-in Functions
# Şu ana kadar kullandığımız len(), print() gibi fonksiyonlar nereden geldi?
#
# Bunlar Python'a "gömülü" olarak var, dolayısıyla herhangi bir işlem yapmadan çalıştırabiliyoruz.

# %% [markdown]
# https://docs.python.org/3/library/functions.html

# %% [markdown]
# Tıpkı bizim yukarıda ortalama bulma, harf notu hesaplama fonksiyonlarımız gibi nice müthiş fonksiyon usta Python yazılımcıları tarafından yazılmış, keşfetmeniz için sizi bekliyor! İşte birkaç örnek 🪁

# %% [markdown]
# # Python Evrenine Açılıyoruz! 🛸

# %% [markdown]
# Başka yazılımcıların yazdıkları binlerce fonksiyon yazıldıkları amaçlar doğrultusunda özel başlıklar altında derlenir. Fotoğraf editleme kütüphanesi, yapay zeka kütüphanesi gibi özel isimlendirilmiş fonksiyon derlemeleri vardır. Bu derelemelere <strong>kütüphane (library/package)</strong> denir. Peki bu hazinelere nasıl erişeceğiz? Anahtarı <strong>import</strong> kelimesi 🗝️

# %% [markdown]
# ## Seaborn ve Pandas

# %%
import seaborn 
gelir = [100, 215, 136]
ay = ['Ocak','Şubat','Mart']
seaborn.barplot(x=ay, y=gelir)

# %% [markdown]
# Bir kütüphaneyi sürekli kullanacaksak adını kısaltabiliriz:

# %%
# "Bundan böyle sns dediğimde seaborn kütüphanesini kastediyorum" demiş oluyoruz
import seaborn as sns

sns.barplot(x=ay, y=gelir)

# %% [markdown]
# Her seferinde `sns...` şeklinde yazmak istemiyorsak, kütüphaneden istediğimiz fonksiyonu özellikle belirterek çağırabiliriz:

# %%
from seaborn import barplot
barplot(x=ay, y=gelir)

# %% [markdown]
# Hala yapabileceğiniz harika şeylere dair içiniz kıpır kıpır olmadıysa bir adım daha ileri gidelim. İBB açık veri portalından yıllara göre İstanbul toplu taşıma bilet fiyatlarını inceleyelim:

# %%
import pandas as pd
toplu_taşıma = pd.read_excel('https://data.ibb.gov.tr/dataset/902ccd71-c2dc-4d1c-9a80-5dd6de9fa175/resource/8e132527-2eb7-4d68-a549-d224d233ab16/download/toplu-tama-bilet-fiyatlar-2017-2022.xlsx', names=['Yıl','Bilet Türü', 'Fiyatı']).replace({'Öğrenci Kartı':'Öğrenci'})
toplu_taşıma
# Out:
#      Yıl Bilet Türü  Fiyatı
# 0   2017        Tam    2.60
# 1   2017    Öğrenci    1.25
# 2   2017     Sosyal    1.85
# 3   2018        Tam    2.60
# 4   2018    Öğrenci    1.25
# 5   2018     Sosyal    1.85
# 6   2019        Tam    3.50
# 7   2019    Öğrenci    1.70
# 8   2019     Sosyal    2.50
# 9   2020        Tam    3.50
# 10  2020    Öğrenci    1.70
# 11  2020     Sosyal    2.50
# 12  2021        Tam    3.50
# 13  2021    Öğrenci    1.70
# 14  2021     Sosyal    2.50
# 15  2022        Tam    7.67
# 16  2022    Öğrenci    3.74
# 17  2022     Sosyal    5.49
# 18  2022        Tam    7.67
# 19  2022    Öğrenci    3.74
# 20  2022     Sosyal    5.49
# 21  2022        Tam    7.67
# 22  2022    Öğrenci    3.74
# 23  2022     Sosyal    5.49

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=toplu_taşıma, x='Yıl', y='Fiyatı', hue='Bilet Türü')

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.lineplot(data=toplu_taşıma, x='Yıl', y='Fiyatı', hue='Bilet Türü')

# %% [markdown]
# ## Skimage

# %% [markdown]
# Biraz da görsellerle uğraşalım 🌠
#
# skimage kütüphanesinden fotoğraflara erişelim:

# %%
import skimage
kedi = skimage.data.cat()
print(kedi)
# Out:
# [[[143 120 104]
#   [143 120 104]
#   [141 118 102]
#   ...
#   [ 45  27  13]
#   [ 45  27  13]
#   [ 45  27  13]]
#
#  [[146 123 107]
#   [145 122 106]
#   [143 120 104]
#   ...
#   [ 46  29  13]
#   [ 45  29  13]
#   [ 47  30  14]]
#
#  [[148 126 112]
#   [147 125 111]
#   [146 122 109]
#   ...
#   [ 48  28  17]
#   [ 49  29  18]
#   [ 50  30  19]]
#
#  ...
#
#  [[ 92  58  30]
#   [105  71  43]
#   [132  98  71]
#   ...
#   [172 145 138]
#   [172 145 138]
#   [172 145 138]]
#
#  [[128  92  60]
#   [139 103  71]
#   [134  95  64]
#   ...
#   [166 142 132]
#   [166 142 132]
#   [167 143 133]]
#
#  [[139 103  71]
#   [127  88  57]
#   [125  86  53]
#   ...
#   [161 137 127]
#   [161 137 127]
#   [162 138 128]]]

# %% [markdown]
# Ah, bu pek beklediğimiz bir şey değildi 🙄 Görüntüleyebilmek için bir başka kütüphaneye ihtiyacımız var: matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(kedi, cmap='gray')        
plt.axis('off')    
plt.show()

# %% [markdown]
# Bundan sonra kolaylık olması açısından görüntüleme fonksiyonu oluşturalım:

# %%
import matplotlib.pyplot as plt
def görüntüle(resim):
  plt.imshow(resim, cmap='gray')        
  plt.axis('off')    
  plt.show()

# %%
görüntüle(kedi)

# %%
import numpy
kedi_döndür = numpy.fliplr(kedi)
görüntüle(kedi_döndür)

# %% [markdown]
# Şimdi biraz da filtreler 📷

# %%
from skimage.color import rgb2gray

# Kedi resmini siyah beyaz yapalım
gri_kedi = rgb2gray(kedi)

# Orijinal resim
görüntüle(kedi)

# Siyah beyaz resim
görüntüle(gri_kedi)

# %% [markdown]
# https://scikit-image.org/docs/stable/api/skimage.data.html

# %%
from skimage.filters import gaussian
gaussian_kedi = gaussian(kedi, multichannel=True)
görüntüle(gaussian_kedi)

# %%
gaussian_kedi = gaussian(kedi, sigma=5, multichannel=True)
görüntüle(gaussian_kedi)

# %%
from skimage.filters import sobel

# Apply edge detection filter
edge_sobel = sobel(gri_kedi)

# Show original and resulting image to compare
görüntüle(kedi)
görüntüle(edge_sobel)

# %% [markdown]
# ## Cowsay

# %% [markdown]
# Bazı kütüphaneler Colab'e halihazırda yüklü. Colab'de olmayan kütüphaneler için `!pip install ...` şeklinde bir kod yazıyoruz.
#
# Kendi bilgisayarımızda ise Colab'de yüklü olan hiçbir kütüphane yüklü değil. Dolayısıyla internetten "how to install ... python package" şeklinde bir arama sonucunda bilgisayarımızda command line'a ne yazmamız gerektiğiniz öğrenebiliriz.

# %% [markdown]
# https://github.com/VaasuDevanS/cowsay-python

# %%
# !pip install cowsay
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for cowsay: filename=cowsay-5.0-py2.py3-none-any.whl size=25724 sha256=84168eb6f65cd3854305b4d7f7870a2ce16bb8f15826e9600fec2f87a28301e6
#   Stored in directory: /root/.cache/pip/wheels/ec/64/04/df66e4b3e5afa8fc293c3c5fae0269a55b80f381d833010aeb
# Successfully built cowsay
# ...

# %%
import cowsay
isim = input('isminizi yazınız: ')
print(cowsay.get_output_string('trex', f'Kodlamayla uğraşmaktan derslerini ihmal ediyorsun gibi görünüyor {isim}!'))
# Out:
# isminizi yazınız: Ali
#   _________________________________________________
#  /                                                 \
# | Kodlamayla uğraşmaktan derslerini ihmal ediyorsun |
# |  gibi görünüyor Ali!                              |
#  \                                                 /
# ...
#                                                         \
#                                                          \
#                                                           \
#                                                            \
#                                                               .-=-==--==--.
#                                                         ..-=="  ,'o`)      `.
#                                                       ,'         `"'         \
#                                                      :  (                     `.__...._
#                                                      |                  )    /         `-=-.
# ...

# %% [markdown]
# ## ASCII Art

# %%
# !pip install art
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 592 kB 5.3 MB/s
# ...

# %%
import art

# %%
print(art.text2art("Bu harika!"))
# Out:
#  ____           _                   _  _            _
# | __ )  _   _  | |__    __ _  _ __ (_)| | __  __ _ | |
# |  _ \ | | | | | '_ \  / _` || '__|| || |/ / / _` || |
# | |_) || |_| | | | | || (_| || |   | ||   < | (_| ||_|
# |____/  \__,_| |_| |_| \__,_||_|   |_||_|\_\ \__,_|(_)

# %%
print(art.text2art('''Lorem  
ipsum 
dolor''', font="small"))
# Out:
#  _
# | |    ___  _ _  ___  _ __
# | |__ / _ \| '_|/ -_)| '  \
# |____|\___/|_|  \___||_|_|_|
#
#  _
# (_) _ __  ___ _  _  _ __
# | || '_ \(_-<| || || '  \
# |_|| .__//__/ \_,_||_|_|_|
#    |_|
#     _       _
#  __| | ___ | | ___  _ _
# / _` |/ _ \| |/ _ \| '_|
# \__,_|\___/|_|\___/|_|

# %% [markdown]
# ## Wikipedia

# %%
# !pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import wikipedia
result = wikipedia.page("İstanbul")
print(result.content)
# Out:
# Istanbul ( IST-an-BUUL, US also  IST-an-buul; Turkish: İstanbul [isˈtanbuɫ] (listen)), formerly known as Constantinople (Greek: Κωνσταντινούπολις; Latin: Constantinopolis), is the largest city in Turkey, serving as the country's economic, cultural and historic hub. The city straddles the Bosporus strait, lying in both Europe and Asia, and has a population of over 15 million residents, comprising 19% of the population of Turkey. Istanbul is the most populous European city, and the world's 15th-largest city.
# The city was founded as Byzantium (Byzantion) in the 7th century BCE by Greek settlers from Megara. In 330 CE, the Roman emperor Constantine the Great made it his imperial capital, renaming it first as New Rome (Nova Roma) and then as Constantinople (Constantinopolis) after himself. The city grew in size and influence, eventually becoming a beacon of the Silk Road and one of the most important cities in history.
# ...

# %% [markdown]
# ## NLTK

# %% [markdown]
# NLTK temel dil işleme kütüphanelerinden biri.

# %%
import nltk # natural language toolkit
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
sentence = 'The Autobiography of Malcolm X was published in 1965, the result of a collaboration between human rights activist Malcolm X and journalist Alex Haley.'
print(nltk.word_tokenize(sentence))
# Out:
# ['The', 'Autobiography', 'of', 'Malcolm', 'X', 'was', 'published', 'in', '1965', ',', 'the', 'result', 'of', 'a', 'collaboration', 'between', 'human', 'rights', 'activist', 'Malcolm', 'X', 'and', 'journalist', 'Alex', 'Haley', '.']

# %% [markdown]
# NLTK ve Wikipedia kütüphanelerini beraber kullanabiliriz. Öncelikle İstanbul sayfasında geçen kelimeleri bir listeye dönüştürelim

# %%
istanbul = wikipedia.page("İstanbul").content
kelimeler = nltk.word_tokenize(istanbul)
print(kelimeler)
# Out:
# ['Istanbul', '(', 'IST-an-BUUL', ',', 'US', 'also', 'IST-an-buul', ';', 'Turkish', ':', 'İstanbul', '[', 'isˈtanbuɫ', ']', '(', 'listen', ')', ')', ',', 'formerly', 'known', 'as', 'Constantinople', '(', 'Greek', ':', 'Κωνσταντινούπολις', ';', 'Latin', ':', 'Constantinopolis', ')', ',', 'is', 'the', 'largest', 'city', 'in', 'Turkey', ',', 'serving', 'as', 'the', 'country', "'s", 'economic', ',', 'cultural', 'and', 'historic', 'hub', '.', 'The', 'city', 'straddles', 'the', 'Bosporus', 'strait', ',', 'lying', 'in', 'both', 'Europe', 'and', 'Asia', ',', 'and', 'has', 'a', 'population', 'of', 'over', '15', 'million', 'residents', ',', 'comprising', '19', '%', 'of', 'the', 'population', 'of', 'Turkey', '.', 'Istanbul', 'is', 'the', 'most', 'populous', 'European', 'city', ',', 'and', 'the', 'world', "'s", '15th-largest', 'city', '.', 'The', 'city', 'was', 'founded', 'as', 'Byzantium', '(', 'Byzantion', ')', 'in', 'the', '7th', 'century', 'BCE', 'by', 'Greek', 'settlers', 'from', 'Megara', '
# ...

# %% [markdown]
# İstanbul kelimesi kaç kere geçmiş bulalım:

# %%
kelimeler.count('Istanbul')
# Out:
# 209

# %% [markdown]
# Kaç farklı kelime olduğunu bulalım, fakat önce listedeki parantez, virgül gibi kelime olmayan karakterleri temizleyelim.

# %%
sözlük = []
for kelime in kelimeler:
  if kelime in "#$%&\'()*+,-./:;<==>?@[\\]^_`{|}~":
    continue

  if kelime not in sözlük:
    sözlük.append(kelime)

print(sözlük)
# Out:
# ['Istanbul', 'IST-an-BUUL', 'US', 'also', 'IST-an-buul', 'Turkish', 'İstanbul', 'isˈtanbuɫ', 'listen', 'formerly', 'known', 'as', 'Constantinople', 'Greek', 'Κωνσταντινούπολις', 'Latin', 'Constantinopolis', 'is', 'the', 'largest', 'city', 'in', 'Turkey', 'serving', 'country', "'s", 'economic', 'cultural', 'and', 'historic', 'hub', 'The', 'straddles', 'Bosporus', 'strait', 'lying', 'both', 'Europe', 'Asia', 'has', 'a', 'population', 'of', 'over', '15', 'million', 'residents', 'comprising', '19', 'most', 'populous', 'European', 'world', '15th-largest', 'was', 'founded', 'Byzantium', 'Byzantion', '7th', 'century', 'BCE', 'by', 'settlers', 'from', 'Megara', 'In', '330', 'CE', 'Roman', 'emperor', 'Constantine', 'Great', 'made', 'it', 'his', 'imperial', 'capital', 'renaming', 'first', 'New', 'Rome', 'Nova', 'Roma', 'then', 'after', 'himself', 'grew', 'size', 'influence', 'eventually', 'becoming', 'beacon', 'Silk', 'Road', 'one', 'important', 'cities', 'history', 'served', 'an', 'for', 'alm
# ...

# %% [markdown]
# Epey temizlendi, peki son olarak hangi kelimenin kaç kere geçtiğini bulabilir misiniz?
