# %% [markdown]
# # Alıştırmalar

# %% [markdown]
# ## 1.Alıştırma
# Aşağıdaki çıktıyı _ekrana yazdıran_ __kargo__ adında bir fonksiyon yazalım:
#
# ```
# Merhaba,
# Kargonuz yola çıkmıştır.
# İyi günler dileriz.
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi
kargo()

# %% [markdown]
# ## 2.Alıştırma
# Bu sefer aşağıdaki çıktıyı _ekrana yazdıran_ __parametreli__ bir __kargo__ fonksiyonu yazalım.
#
# ```
# Merhaba Ali,
# Kargonuz yola çıkmıştır.
# İyi günler dileriz.
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi
kargo('Ahmet')

# %% [markdown]
# ## 3.Alıştırma
# Input ile 2 sayı alalım. Bu sayıları kıyas eden bir __kıyas__ fonksiyonu yazalım. Fonksiyonlar sonuçları bize __return__ olarak versin. Biz de bu çıktıyla kullanıcıya bilgi verelim.
#
# İlk örnek
# ```
# Lütfen ilk sayıyı yazınız: 10
# Lütfen ikinci sayıyı yazınız: 20
#
# ilk sayı ikinciden büyüktür.
# ```
#
# İkinci örnek
# ```
# Lütfen ilk sayıyı yazınız: 30
# Lütfen ikinci sayıyı yazınız: 15
#
# ikinci sayı ilkinden büyüktür.
# ```
# Üçüncü örnek
# ```
# Lütfen ilk sayıyı yazınız: 15
# Lütfen ikinci sayıyı yazınız: 15
#
# İki sayı birbirine eşittir.
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi
kıyas(3,5)

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi
kıyas(10,4)

# %% [markdown]
# ## 4.Alıştırma
# Toplama ve çıkarma fonksiyonları yazalım. İlk notlardaki bir alıştırmada 4 işlemi yeni öğrenen birine yardımcı olacak bir program yazmıştık. while loop ile hazırlayacağınız bu programda artık dilediği kadar matematik çalışabilir!

# %% [markdown]
# ## 5.Alıştırma
# Verilen listeyi tersten yazan bir fonksiyon yazalım:
#
# ```
# ters_cevir([1,2,3,4])
# ```
# ```
# [4,3,2,1]
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi: [13,12,11,10] şeklinde bir çıktı vermeli
ters_cevir([10,11,12,13])

# %% [markdown]
# ## 6.Alıştırma
# Bir stringde aradığımız kelime veya harfin kaç kere geçtiğini veren bir fonksiyon yazalım.
#
#
#
# ```
# say('bu cümlede kaç tane k var?')
# ```
# ```
# Bu cümlede 2 tane k var.
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi
say('bu cümlede geçen a harflerinin sayısını bulabilir miyiz?')

# %% [markdown]
# ## 7.Alıştırma
# Verilen stringin ilk harfini veren bir fonksiyon yazalım.
# ```
# ilk_harf('Adem')
# ```
# ```
# Adem kelimesinin ilk harfi A
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi: Kerem kelimesinin ilk harfi K yazmalı
ilk_harf('Kerem')

# %% [markdown]
# ## 8.Alıştırma
#
# Daha önce bir listedeki elemanların toplamını bir for döngüsü kullanarak bulmuştuk.
#
# ```
# market = [496, 204, 251, 318, 209, 554, 241, 468, 274, 369]
# toplam = 0
# for masraf in market:
#   toplam += masraf
# print(toplam)
# ```
# Birkaç tane listemiz olsaydı ve biz bunların toplamlarını elde etmek isteseydik?
#
#
# ```
# yıllar = [1956, 1928, 1984, 1903, 1902, 1909, 1906, 1932, 2009, 1996]
# puanlar = [93, 23, 91, 75, 79, 95, 40, 69, 75, 85]
# ```
#
# Verilen listenin toplamını bulan __liste_toplam__ adında bir fonksiyon yazalım.

# %%
yıllar = [1956, 1928, 1984, 1903, 1902, 1909, 1906, 1932, 2009, 1996]
puanlar = [93, 23, 91, 75, 79, 95, 40, 69, 75, 85]

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi: yıllar listesinin toplamını vermeli
liste_toplam(yıllar)

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi: puanlar listesinin toplamını vermeli
liste_toplam(puanlar)

# %% [markdown]
# ## 9.Alıştırma
# Verilen listedeki tek sayıları liste halinde veren bir fonksiyon yazalım.
#
# ```
# tek_sayılar([1,2,3,4,5,6])
# ```
# ```
# [1,3,5]
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi: [21,25]'i vermeli
tek_sayılar([20,21,22,25])

# %% [markdown]
# ## 10.Alıştırma
# İki listedeki ortak elemanları veren bir fonksiyon yazalım.
# ```
# ortak([1,2,3,4,5,6],[1,5,6])
# ```
# ```
# [1,5,6]
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi: b ve c'yi vermeli
ortak(["a","b","c"],["b","c"])

# %% [markdown]
# ## 11.Alıştırma
# 3 parametreli bir fonksiyon yazalım.
#
# 1. string
# 2. tekrar sayısı
# 3. alt alta mı yan yana mı?
#
# ```
# tekrar_et('a',5,yanyana=True)
# ```
# ```
# aaaaa
# ```
#
# ----
# ```
# tekrar_et('a',5,yanyana=False)
# ```
# ```
# a
# a
# a
# a
# a
# ```

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi:
tekrar_et('x',3,yanyana=True)

# %%
# Yukarıda tanımlayacağınız fonksiyonun denemesi:
tekrar_et('x',3,yanyana=False)

# %% [markdown]
# ## BONUS: To-do Uygulaması
# Bir To-do uygulaması yazalım 🤗
#
# Kullanıcılarımızın uygulamamızda yapabilecekleri:
# 1. Yeni bir görev ekleme
# 2. Var olan görevi silme
# 3. Var olan görevlerden birini tamamlama
# 4. Günlük görev listesini görüntüleme
# 5. Tamamlanmış olan görevleri görüntüleme
# 6. Günlük görevlerini bir text dosyası olarak kaydetme
