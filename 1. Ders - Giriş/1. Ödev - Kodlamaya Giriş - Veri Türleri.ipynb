# %% [markdown]
# Ödevi online olarak yapabilmek için tıklayınız:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/15QFMM5C2tW6oA9T4fDfxRympol0jL_n7?usp=share_link)

# %% [markdown]
# # Python ile Kodlamaya Giriş

# %% [markdown]
# __Önemli not:__
#
# Yaptıklarınızın silinmemesi için bu notu kendi drive'ınıza kaydetmelisiniz. Bunun için sol üstteki File kısmından "Save a copy in Drive" seçeneğine tıklamalısınız.

# %% [markdown]
# Küçük bir not:
#
# Kullanıcıdan input aldığımız alıştırmalarda örnek ekran kısmındaki inputlar tek seçenek değil, dolayısıyla kodunuz farklı inputlarla da çalışabilmeli.

# %% [markdown]
# ## Alıştırmalar

# %% [markdown]
# ### 1\. Alıştırma
#
# Aşağıdaki çıktıyı ekrana yazdıralım.
# ```
# Python muazzam bir şey!
# ```

# %% [markdown]
# ### 2\. Alıştırma
# Bir input ile kullanıcıdan ismini alalım. Yazdığımız kod aşağıdaki gibi bir çıktı versin.
#
# Örnek ekran:
# ```
# İsminizi yazınız: Ali
# Seni aramızda görmek harika Ali!
# ```

# %% [markdown]
# ### 3\. Alıştırma
# Kullanıcıdan 2 input alalım:
# 1. Film adı
# 2. Filmin vizyona girme tarihi
#
# Son olarak bu iki bilgiyi birleştiren bir print yapalım.
#
# Örnek ekran:
# ```
# Film adını yazınız: The Dark Knight
# Vizyona girme tarihi: 2008
# "The Dark Knight" filmi 2008 yılında vizyona girmiştir.
# ```

# %% [markdown]
# ### 4\. Alıştırma
# Bir önceki alıştırmayı biraz değiştirelim.
#
# Kullanıcıdan yine 2 input alalım:
# 1. Film adı
# 2. Filmin vizyona girme tarihi
#
# Bu sefer ekrana yazdırdığımız son cümleyi değiştirelim.
#
# Örnek ekran:
# ```
# Film adını yazınız: The Dark Knight
# Vizyona girme tarihi: 2008
# "The Dark Knight" filmi 14 yıl önce vizyona girmiştir.
# ```

# %% [markdown]
# ### 5\. Alıştırma
# Karşı komşunuzun ilkokula giden tatlı çocuğuna toplama işlemlerinde yardımcı oluyordunuz, fakat işiniz sebiyle başka bir şehre taşınmanız gerektiğini öğrendiniz😔 Ona artık yardım edemeyeceğinizi tam söyleyecekken aklınıza harika bir fikir geldi! Toplama işlemlerini doğru yapıp yapmadığını test edeceği bir program yazmaya karar verdiniz😇
#
# Örnek ekran:
# ```
# İlk sayıyı buraya yazabilirsin: 10
# İkinci sayıyı da buraya: 15
# 10 + 15 = 25
# ```

# %% [markdown]
# ### 6\. Alıştırma
# Aylık masraflarını hesaplamak isteyen bir öğrenciye işlerini kolaylaştıracak bir program yazmaya niyetlendik 🤓 Input ile almamız gereken bilgiler:
#
# 1. Öğrencinin ismi
# 2. Aylık harçlığı
# 3. Yemekhanedeki yemek fiyatı
# 4. Kaç gün okula gittiği
# 5. Ulaşım ücreti
# 6. Ek harcamalar
#
# En son cebine kalacak parayı çıktı olarak verebiliriz.
#
#
#
# ```
# Zehra, bu ay cebine kalan para: .. TL
# ```

# %% [markdown]
# ### 7\. Alıştırma
#
# Yeni bir bilgisayara ihtiyacınız var, yurt dışından getirtmeye karar verdiniz. Bütçenizi TL olarak, yurt dışından getirilecek olan bilgisayarı dolar olarak input alalım. Dolar kurunu nasıl isterseniz belirleyebilirsiniz. Neticede aşağıdaki 2 çıktıdan birisi olsun:
# ```
# bütçe(TL): 5000
# bilgisayar($): 1000
# Üzgünüm, bütçen bu bilgisayar için yeterli değil :/
# ```
# ```
# bütçe(TL): 30000
# bilgisayar($): 2000
# Bilgisayarı alabilirsin, güle güle kullan :)
# ```

# %% [markdown]
# ### 8\. Alıştırma
# Kullanıcıya ruh halini soralım, ona göre bir şarkı tavsiye edelim✨
#
# Kolaylık olması açısından kullanıcıya yazabileceği 4 farklı ruh halini söyleyelim:
# 1. Neşeli
# 2. Üzgün
# 3. Karamsar
# 4. Huzurlu
#
# Örnek ekran:
# ```
# Ruh haliniz (Neşeli/Üzgün/Karamsar/Huzurlu): Neşeli
# Size önereceğimiz şarkı ...
# Neşeniz daim olsun!
# ```
#
# Şarkı tavsiyelerinizi ve beraberindeki cümleleri nasıl isterseniz yazabilirsiniz 😎

# %% [markdown]
# ### 9\. Alıştırma
#
# Input ile vize ve final notlarını alalım.
#
# `(vize notu x 0.4) + (final notu x 0.6)` ile not ortalamasını bulalım.
#
# 90-100 arası ise
# > Ortalamanız ... ve harf notunuz A'dır. Tebrikler!
#
# 80-90 arası ise
# > Ortalamanız ... ve harf notunuz B'dir.
#
# 70-80 arası ise
# > Ortalamanız ... ve harf notunuz C'dir.
#
# 60-70 arası ise
# > Ortalamanız ... ve harf notunuz D'dir. (Ucuz atlattın)
#
# 60'tan düşük  ise
# > Ortalamanız ... maalesef dersten kaldın :(

# %% [markdown]
# ### 10\. Alıştırma
# Kod öğrenmeye yeni başlayan arkadaşınız aşağıdaki satırları yazmış fakat neden çalışmadığını anlayamamış, sizin bu işlerden anladığınızı bildiği için hemen size danışmaya karar vermiş 🤗

# %%
print(Python nefis bir şey!)

# %%
kullanıcı yaşı = input('Yaşınızı giriniz:)
print("kullanıcı yaşı")

# %%
isim = input("isminizi yazınız:")
if isim = Yusuf:
print("Yusuf! ne zamandır görünmüyorsun?")
else:
print("Merhaba"+isim)

# %%
telefon1 = input("ilk telefonun ücretini yazınız: ")
telefon2 = input("ilk telefonun ücretini yazınız: ")



if telefon1 > telefon2
fiyat_farkı = telefon1 - telefon2
print("İlk telefonun fiyatı" + fiyat_farkı + "TL kadar daha uygun.")

elif telefon2 > telefon1
fiyat_farkı = telefon2 - telefon1
print("İkinci telefonun fiyatı" + fiyat_farkı + "TL kadar daha uygun.")

else:
print("Telefon fiyatları birbirine eşit.")

# %% [markdown]
# ### Bonus Alıştırma
#
# Aşağıdaki tabloyu bir programa dönüştürebilir miyiz?
#
# Önce doktora seçenekleri print ile gösterelim:
# 1. HbA1c
# 2. Açlık glukoz şekeri
# 3. Oral glukoz tolerans testi
#
# Ardından hangi değer üzerinden değerlendirme yapmak istediğini seçmesini isteyelim. Ardından değeri girmesini isteyelim. Neticede **diyabet, prediyabet, normal** şeklinde 3 cevaptan birini verelim.
#
# Örnek ekranlar:
# ```
# 1. HbA1c
# 2. Açlık glukoz şekeri
# 3. Oral glukoz tolerans testi
# Lütfen hangi değeri gireceğinizi belirtin (1, 2 ya da 3 yazıp enter'a basın): 2
# Değeri girin: 130
# Açlık glukoz değeri 130, hastanız diyabet hastasıdır.
# ```
# ```
# 1. HbA1c
# 2. Açlık glukoz şekeri
# 3. Oral glukoz tolerans testi
# Lütfen hangi değeri gireceğinizi belirtin (1, 2 ya da 3 yazıp enter'a basın): 1
# Değeri girin: 2
# HbA1c değeri 2, hastanızın diyabet problemi bulunmamaktadır.
# ```
# ```
# 1. HbA1c
# 2. Açlık glukoz şekeri
# 3. Oral glukoz tolerans testi
# Lütfen hangi değeri gireceğinizi belirtin (1, 2 ya da 3 yazıp enter'a basın): 3
# Değeri girin: 150
# Oral glukoz tolerans testi değeri 150, hastanızın prediyabetiktir.
# ```
#
#
# ![diabetes.png](data:image/png;base64,...)
